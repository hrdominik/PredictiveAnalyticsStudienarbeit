# %% [markdown]
# # Daily Financial News for 6000+ Stocks
# ### Sentimentanalysis-Modelling of Headlines for Stocks and there prices
# @author DHR <br>
# @author BKN <br>

# %% [markdown]
# ## Requirements

# %%
#immport basic DataScience Modules
#!! for pip-modul-list to install @see requirements.txt
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
# import final DataSet for Modelling
data = pd.read_csv('../data/analyst_ratings_processed_final.csv')

# %%
# data = data[:1000]

# %%
def stockDevelopement(row):
    # stock_differenz = row['open'] - row['close']
    quotient = row['close']/row['open']
    if quotient < 0.9:
        return -1
    elif quotient > 1.1:
        return 1
    else: return 0

# %%
data["stockPriceIncreased"] = data.apply(stockDevelopement, axis=1)

# %%
def getBinarySenti(row):
    if row["senti_score"] < 0:
        return -1
    elif row['senti_score'] > 0:
        return 1
    else: return 0

# %%
data['sentiBinary'] = data.apply(getBinarySenti, axis=1)

# %%
def checkAccuracy(row):
    if row['stockPriceIncreased'] == row["sentiBinary"]:
        return 1
    else: return 0

# %%
data["accuracy"] = data.apply(checkAccuracy, axis=1)

# %%
data.sample(10)
# Out:
#              id                                           headline  \
# 27250    229752  SunTrust Robinson Humphrey Maintains Buy on Ce...
# 137436  1216151  Shares of several financial services companies...
# 40726    343217  Shares of several basic materials companies ar...
# 57882    503401  Shares of several industrial companies are tra...
# 101667   897241  Alibaba, Tesla Among Cramer's Stay-At-Home Sto...
# 149243  1295720  Trump's Comments On USPS Rates May Not Square ...
# 87755    782622  DA Davidson Maintains Buy on Louisiana-Pacific...
# 75972    662390  The Daily Biotech Pulse: Novartis Program Plac...
# 119114  1046359  From Pioneer Natural Resources Earnings Confer...
# 87838    783535  KeyBanc Maintains Overweight on Lam Research, ...
#
#                                                       url  \
# 27250   https://www.benzinga.com/news/20/03/15672506/s...
# 137436  https://www.benzinga.com/wiim/20/03/15605475/s...
# 40726   https://www.benzinga.com/wiim/20/02/15408322/s...
# 57882   https://www.benzinga.com/wiim/20/05/15933139/s...
# 101667  https://www.benzinga.com/trading-ideas/long-id...
# 149243  https://www.benzinga.com/government/20/04/1580...
# 87755   https://www.benzinga.com/news/20/05/15967090/d...
# 75972   https://www.benzinga.com/general/biotech/19/10...
# 119114  https://www.benzinga.com/news/20/05/15979041/f...
# 87838   https://www.benzinga.com/news/20/04/15863451/k...
#
#                       publisher        date stock  \
# 27250                Vick Meyer  2020-03-26  CERN
# 137436        Benzinga Newsdesk  2020-03-19    TD
# 40726         Benzinga Newsdesk  2020-02-25    DD
# 57882         Benzinga Newsdesk  2020-05-01   FLS
# 101667              Craig Jones  2020-04-16  NFLX
# 149243             FreightWaves  2020-04-15   UPS
# 87755                Vick Meyer  2020-05-06   LPX
# 75972          Shanthi Rexaline  2019-10-30  IMMU
# 119114        Benzinga Newsdesk  2020-05-07   PXD
# 87838   vishwanath@benzinga.com  2020-04-23  LRCX
#
#                                          headline_cleaned  senti_pos_score  \
# 27250   ['robinson.n.01', 'bargain.n.02', 'lower_berth...            0.500
# 137436  ['share.n.01', 'several.s.01', 'fiscal.a.01', ...            0.375
# 40726   ['share.n.01', 'several.s.01', 'basic.a.01', '...            0.125
# 57882   ['share.n.01', 'several.s.01', 'industrial.a.0...            0.000
# 101667  ['tesla.n.01', 'stay-at-home.s.01', 'stock.n.0...            0.125
# 149243  ['trump.n.01', 'remark.n.01', 'united_states_p...            0.000
# 87755   ['bargain.n.02', 'lower_berth.n.01', 'monetary...            0.500
# 75972   ['daily.n.01', 'biotechnology.n.01', 'pulsatio...            0.000
# 119114  ['pioneer.n.01', 'natural.n.01', 'resource.n.0...            0.000
# 87838   ['corpulence.n.01', 'getaway.n.02', 'research....            0.000
#
#         senti_neg_score  senti_score    open   close  stockPriceIncreased  \
# 27250             0.125        0.375   57.82   61.04                    0
# 137436            2.875       -2.500   37.04   37.43                    0
# 40726             1.125       -1.000   50.50   47.47                    0
# 57882             1.125       -1.125   27.60   26.55                    0
# 101667            0.625       -0.500  437.00  439.17                    0
# 149243            0.000        0.000   99.94   99.92                    0
# 87755             0.125        0.375   19.85   20.32                    0
# 75972             0.000        0.000   15.83   15.82                    0
# 119114            0.125       -0.125   85.01   87.02                    0
# 87838             0.125       -0.125  268.85  263.96                    0
#
#         sentiBinary  accuracy
# 27250             1         0
# 137436           -1         0
# 40726            -1         0
# 57882            -1         0
# 101667           -1         0
# 149243            0         1
# 87755             1         0
# 75972             0         1
# 119114           -1         0
# 87838            -1         0

# %%
numberRowsCorrect = data[data["accuracy"] == 1].shape[0]
numberRows = data.shape[0]
accuracy = numberRowsCorrect / numberRows
print("Von " + str(numberRows) + " wurden " + str(numberRowsCorrect) +" richtig erkannt. Das ergbit eine Accuracy von: " + str(accuracy))
# Out:
# Von 161478 wurden 61517 richtig erkannt. Das ergbit eine Accuracy von: 0.3809621124859114
